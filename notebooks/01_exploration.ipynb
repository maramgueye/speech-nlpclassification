# %% [markdown]
# ### NOTEBOOK 01 : DATA EXPLORATION & PREPARATION
# Objectif : Load Common Voice, explore the demographic and prepare the pipeline for emotional recognition

# %% [markdown]
# ### 1. Installation and Import of the libraries

# %%
# !pip install datasets pandas numpy matplotlib seaborn librosa soundfile whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 876.7 kB/s eta 0:00:00MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for whisper: filename=whisper-1.1.10-py3-none-any.whl size=41198 sha256=02ae7f43249fb65a7d97ef0866c05ca0b6f7e4157dfe95f616fadfa759467db8
#   Stored in directory: /home/marameeee/.cache/pip/wheels/21/65/ee/4e6672aabfa486d3341a39a04f8f87c77e5156149299b5a7d0
# Successfully built whisper
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import load_dataset
from collections import Counter
import warnings

# %% [markdown]
# ### Chargement du dataset RAVDEES (to have Speech Emotion Recognition)

# %% [markdown]
# **Pourquoi RAVDESS ?**
# Je voulais au debut utiliser Common Voice qui est plus connus mais cela n'a pas fonctionne.
# RAVDESS est libre d'accès, en anglais, et parfait pour la classification d'émotions, il s'est ainsi presente comme une tres bonne base de donnees pour mon projet.
#
# - Émotions : `neutral`, `calm`, `happy`, `sad`, `angry`, `fearful`, `disgust`, `surprised`

# %%
from datasets import load_dataset
import pandas as pd
import numpy as np

# %%
try:
    dataset = load_dataset("xbgoose/ravdess", split="train")
    df = dataset.to_pandas()
    print(f"Dataset chargé avec succès")
    print(f"{df.shape[0]} lignes × {df.shape[1]} colonnes")
    print(f"\nAperçu des colonnes disponibles :")
    print(df.dtypes)
    print(f"\nPremières lignes :")
    df.head()

except Exception as e:
    print(f"Erreur : {e}")
# Out:
# ✅ RAVDESS chargé avec succès
# 📊 Taille : 1440 enregistrements
#                                                audio    modality  \
# 0  {'bytes': b'RIFFH\xa2\x06\x00WAVEfmt \x10\x00\...  audio-only
# 1  {'bytes': b'RIFF$%\x06\x00WAVEfmt \x10\x00\x00...  audio-only
# 2  {'bytes': b'RIFF\xb4c\x06\x00WAVEfmt \x10\x00\...  audio-only
# 3  {'bytes': b'RIFFL\xbb\x06\x00WAVEfmt \x10\x00\...  audio-only
# 4  {'bytes': b'RIFF6p\x06\x00WAVEfmt \x10\x00\x00...  audio-only
#
#   vocal_channel  emotion emotional_intensity                     statement  \
# 0        speech    angry              normal  Dogs are sitting by the door
# 1        speech  fearful              normal  Dogs are sitting by the door
# 2        speech  fearful              strong  Kids are talking by the door
# 3        speech    angry              strong  Kids are talking by the door
# 4        speech  disgust              normal  Kids are talking by the door
#
#        repetition  actor  gender
# ...

# %%
# !pip install openai-whisper librosa soundfile datasets huggingface_hub
# !pip install transformers torch scikit-learn tensorflow
# !pip install numpy pandas matplotlib seaborn scipy tqdm
# !pip install nltk
# Out:
# ...
#   Using cached openai_whisper-20250625.tar.gz (803 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Obtaining dependency information for more-itertools from https://files.pythonhosted.org/packages/cb/98/6af411189d9413534c3eb691182bff1f5c6d44ed2f93f2edfe52a1bbceb8/more_itertools-11.0.2-py3-none-any.whl.metadata
#   Using cached more_itertools-11.0.2-py3-none-any.whl.metadata (41 kB)
# ...
#   Obtaining dependency information for tiktoken from https://files.pythonhosted.org/packages/6a/d0/3d9275198e067f8b65076a68894bb52fd253875f3644f0a321a720277b8a/tiktoken-0.12.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata
#   Using cached tiktoken-0.12.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.7 kB)
# ...
